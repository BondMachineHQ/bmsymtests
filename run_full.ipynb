# %%
# Load configuration files and libraries
# %run config.py
# %run config.ipynb

# %%
# From here, it is possible to override the config.py settings and run specific parts, by defining all the variables are set to False

debug=True
runMode="fragtester"
fullRun=True
# storeBM=True
runSimbatchTests=True
# runBmsimTests=True

benchcore=True
data_type="fxps32f4"

functionFile = "generated.py"
regexFilter = "cosargreal"

# %%
# Execute the full run
gs=fullRunTest(debug,benchcore,data_type,runSimbatchTests,runBmsimTests,regexFilter)
# Out:
# Evaluating neuron: cosargreal
# Skipping neuron cosargreal for BMsim tests
