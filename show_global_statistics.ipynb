# %%
# Load configuration files and libraries
# %run config.py
# %run config.ipynb

# %%
# Load data and print plots of latency vs precision
gs=loadGlobalStats()
gs.style.apply(lambda x: x.map(highlightDone), axis=None, subset=['bsimoccurrences', 'bmoccurrences'])
